# %%
import numpy as np
import matplotlib.pyplot as plt  
import pandas as pd

# %%
data = pd.read_csv('data/grouped_audio_billboard_genre_data.csv')
data
# Out:
#                                                 track_id    genre  \
# 0                          AdictoTainy, Anuel AA & Ozuna      pop
# 1      The Ones That Didn't Make It Back HomeJustin M...  country
# 2                      ShallowLady Gaga & Bradley Cooper      pop
# 3                    EnemiesPost Malone Featuring DaBaby      rap
# 4        Bacc At It AgainYella Beezy, Gucci Mane & Quavo      rap
# ...                                                  ...      ...
# 28370              Tonight, TonightThe Smashing Pumpkins     rock
# 28371  Tonight's The Night (Gonna Be Alright)Rod Stewart     rock
# 28372                     Tonight's The NightBLACKstreet      pop
# 28373                          Tonight's The NightS.S.O.    other
# 28374                   Tonight's The NightSolomon Burke     soul
#
#        spotify_track_explicit  spotify_track_duration_ms  \
# 0                         0.0                   270740.0
# 1                         0.0                        0.0
# 2                         0.0                   215733.0
# 3                         1.0                   196760.0
# 4                         1.0                   228185.0
# ...                       ...                        ...
# 28370                     0.0                   254626.0
# 28371                     0.0                   237120.0
# 28372                     0.0                   258026.0
# 28373                     0.0                   170506.0
# 28374                     0.0                   161186.0
#
#        spotify_track_popularity  danceability  energy   key  loudness  mode  \
# 0                          91.0         0.734   0.836  10.0    -4.803   0.0
# 1                           0.0         0.000   0.000   0.0     0.000   0.0
# 2                          89.0         0.572   0.385   7.0    -6.362   1.0
# 3                          86.0         0.542   0.674   6.0    -4.169   1.0
# 4                          61.0         0.948   0.623   8.0    -5.725   0.0
# ...                         ...           ...     ...   ...       ...   ...
# 28370                      69.0         0.287   0.670   6.0    -9.381   1.0
# 28371                      55.0         0.550   0.514  11.0   -12.617   1.0
# 28372                      32.0         0.585   0.573   6.0    -5.561   0.0
# 28373                      13.0         0.000   0.000   0.0     0.000   0.0
# 28374                      28.0         0.318   0.476   7.0    -9.534   1.0
#
#        ...  acousticness  instrumentalness  liveness  valence    tempo  \
# 0      ...      0.017000          0.000016    0.1790    0.623   80.002
# 1      ...      0.000000          0.000000    0.0000    0.000    0.000
# 2      ...      0.371000          0.000000    0.2310    0.323   95.799
# 3      ...      0.058800          0.000000    0.0955    0.667   76.388
# 4      ...      0.001240          0.000001    0.0716    0.856  135.979
# ...    ...           ...               ...       ...      ...      ...
# 28370  ...      0.000063          0.748000    0.2370    0.222  148.928
# 28371  ...      0.336000          0.125000    0.3820    0.724  136.542
# 28372  ...      0.133000          0.000011    0.1730    0.591   76.060
# 28373  ...      0.000000          0.000000    0.0000    0.000    0.000
# 28374  ...      0.401000          0.000000    0.6000    0.633  173.305
#
#        time_signature  week_pos  instance  peak_pos  weeks_on_chart
# 0                 4.0      98.0       1.0      86.0             2.0
# 1                 0.0     100.0       1.0     100.0             1.0
# 2                 4.0      28.0       1.0      28.0             1.0
# 3                 4.0      98.0       1.0      16.0            15.0
# 4                 4.0      94.0       1.0      94.0             3.0
# ...               ...       ...       ...       ...             ...
# 28370             4.0      51.0       1.0      51.0             1.0
# 28371             3.0      81.0       1.0      81.0             1.0
# 28372             4.0      95.0       2.0      95.0             2.0
# 28373             0.0     100.0       1.0     100.0             2.0
# 28374             3.0      80.0       1.0      80.0             1.0
#
# [28375 rows x 21 columns]

# %%
X = data.peak_pos.values.reshape(-1, 1)
y = data.weeks_on_chart.values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (28375, 1) (28375, 1)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [[-0.03158194]]
# y-axis intercept:  [4.0838155]

# %%
x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[1.]]
# Max X Value: [[100.]]

# %%
y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
plt.scatter(X, y, c='blue')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
