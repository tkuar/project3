# %%
from spotipy.oauth2 import SpotifyClientCredentials
import json
import spotipy
import time
import billboard
import requests
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id ="d75f8945ef4f45ffb3131fb970d35488",client_secret ="72a1655f125c48ebb50d611cad3a289e"))
CLIENT_ID ="bf8deb9af9d24627b9a72a326c1ca283"
CLIENT_SECRET ="070c1e7b5f3e411dae8adb754df33ab5"

# %%
chart = billboard.ChartData('hot-100')
print(len(chart))

# >>> song = chart[0]  # Get no. 1 song on chart
# >>> song.title
# 'Nice For What'
# >>> song.artist
# 'Drake'
# >>> song.weeks  # Number of weeks on chart

tracks =[]
artists = []
for i in range(len(chart)):
    tracks.append(chart[i].title)
    artists.append(chart[i].artist)
print(len(tracks))
print(len(artists))
# Out:
# 100
# 100
# 100

# %%
sp.trace = False
# tids = []
# for i in range(100):
#     results = sp.search(q=f"{track[i]}", limit = 1, type="track")
#     print(json.dumps(results, indent=4))

# results = sp.search(q=f"track:{track[0]}",limit = 1, type="track")
# print(json.dumps(results, indent=4))
# print(len(results))
#     for s, t in enumerate(results['tracks']['items']):
#         print(' ', s, t['name'])
#         tids.append(t['uri'])

# start = time.time()
# features = sp.audio_features(tids)
# delta = time.time() - start
# for feature in features:
#     print(json.dumps(feature, indent=4))
#     print()
# print("features retrieved in %.2f seconds" % (delta,))

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

track_ids = []

for track in range(len(tracks)):

    response = requests.get(f"{BASE_URL}search?q={tracks[track]}&type=track&limit=1", headers=headers)

    results = response.json()

    track_ids.append(results["tracks"]["items"][0]["album"]["artists"][0]["id"])

# %%
features = []
start = time.time()
features = sp.audio_features(track_ids)
delta = time.time() - start
for feature in features:
    print(json.dumps(feature, indent=4))
    print()
print("features retrieved in %.2f seconds" % (delta,))
# Out:
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# null
#
# features retrieved in 0.11 seconds

# %%
print(features)
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
print(track_ids)
# Out:
# ['56mfhUDKa1vec6rSLZV5Eg', '3Nrfpe0tUJi4K4DXYWgMUX', '4kYSro6naA4h99UJvo89HB', '6fWVd57NKTalqvmjRd2t8Z', '3TVXtAsR1Inumwj472S9r4', '1Xyo4u8uXC1ZmMpatF05PJ', '4r63FhuTkUYltbVAg5TQnk', '6Iz3eq2aQGFf7TbGT2iahL', '1URnnhqYAYcrqrcwql10ft', '1URnnhqYAYcrqrcwql10ft', '6KImCVD70vtIoJWnq6nGn3', '6MPCFvOQv5cIGfw3jODMF0', '4GNC7GD6oZMSxPGyXy4MNB', '1uNFoZAHBGtllmzznpCI3s', '0eDvMgVFoNV3TpwtrVCoTj', '2LIk90788K0zvyj2JJVwkJ', '7bXgB6jMjp9ATFy66eO08Z', '7n2wHs1TKAczGzO7Dd2rGr', '1URnnhqYAYcrqrcwql10ft', '5Zq7R5qmi58ByYyBQTlNuk', '08GQAI4eElDnROBrJRGE0X', '246dkjvS1zLTtiykXe5h60', '3FfvYsEGaIb52QPXhg4DcH', '4MCBfE4596Uoi2O4DtmEMz', '0Y5tJX1MQlPlqiwlOH1tJY', '1URnnhqYAYcrqrcwql10ft', '3oSJ7TBVCWMDMiYjXNiCKE', '6KImCVD70vtIoJWnq6nGn3', '6M2wZ9GZgrQXHCFfjv46we', '0rvjqX7ttXeg3mTy8Xscbt', '0H39MdGGX6dbnnQPt6NQkZ', '1URnnhqYAYcrqrcwql10ft', '1URnnhqYAYcrqrcwql10ft', '0QHgL1lAIqAw0HtD7YldmP', '6s22t5Y3prQHyaHWUN1R1C', '0eDvMgVFoNV3TpwtrVCoTj', '6KImCVD70vtIoJWnq6nGn3', '4oUHIQIBe0LHzYfvXNW4QM', '6M2wZ9GZ
# ...
