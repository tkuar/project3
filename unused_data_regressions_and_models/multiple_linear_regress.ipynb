# %%
import numpy as np
import matplotlib.pyplot as plt  
import pandas as pd  
from sklearn.linear_model import LinearRegression

# %%
billboard_df = pd.read_csv('data/billboard_hot_100_1958_2019.csv')
audio_df = pd.read_csv('data/audio_features_hot_100_1958_2019.csv')

# %%
billboard_audio = pd.merge(audio_df, billboard_df, how='inner', on = 'track_id')
billboard_audio
# Out:
#                                                  track_id  \
# 0                           AdictoTainy, Anuel AA & Ozuna
# 1                           AdictoTainy, Anuel AA & Ozuna
# 2       The Ones That Didn't Make It Back HomeJustin M...
# 3       The Ones That Didn't Make It Back HomeJustin M...
# 4       The Ones That Didn't Make It Back HomeJustin M...
# ...                                                   ...
# 321013                   Tonight's The NightSolomon Burke
# 321014                   Tonight's The NightSolomon Burke
# 321015                   Tonight's The NightSolomon Burke
# 321016                   Tonight's The NightSolomon Burke
# 321017                   Tonight's The NightSolomon Burke
#
#                        artist_x                                 track_x  \
# 0       Tainy, Anuel AA & Ozuna                                  Adicto
# 1       Tainy, Anuel AA & Ozuna                                  Adicto
# 2                  Justin Moore  The Ones That Didn't Make It Back Home
# 3                  Justin Moore  The Ones That Didn't Make It Back Home
# 4                  Justin Moore  The Ones That Didn't Make It Back Home
# ...                         ...                                     ...
# 321013            Solomon Burke                     Tonight's The Night
# 321014            Solomon Burke                     Tonight's The Night
# 321015            Solomon Burke                     Tonight's The Night
# 321016            Solomon Burke                     Tonight's The Night
# 321017            Solomon Burke                     Tonight's The Night
#
#                                             spotify_genre  \
# 0                                       ['pop reggaeton']
# 1                                       ['pop reggaeton']
# 2       ['arkansas country', 'contemporary country', '...
# 3       ['arkansas country', 'contemporary country', '...
# 4       ['arkansas country', 'contemporary country', '...
# ...                                                   ...
# 321013  ['brill building pop', 'classic soul', 'funk',...
# 321014  ['brill building pop', 'classic soul', 'funk',...
# 321015  ['brill building pop', 'classic soul', 'funk',...
# 321016  ['brill building pop', 'classic soul', 'funk',...
# 321017  ['brill building pop', 'classic soul', 'funk',...
#
#               spotify_track_id             spotify_track_album  \
# 0       3jbT1Y5MoPwEIpZndDDwVq  Adicto (with Anuel AA & Ozuna)
# 1       3jbT1Y5MoPwEIpZndDDwVq  Adicto (with Anuel AA & Ozuna)
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                             NaN
# ...                        ...                             ...
# 321013  18TM70njJRFH4Fm4ZuwLd8  The Very Best Of Solomon Burke
# 321014  18TM70njJRFH4Fm4ZuwLd8  The Very Best Of Solomon Burke
# 321015  18TM70njJRFH4Fm4ZuwLd8  The Very Best Of Solomon Burke
# 321016  18TM70njJRFH4Fm4ZuwLd8  The Very Best Of Solomon Burke
# 321017  18TM70njJRFH4Fm4ZuwLd8  The Very Best Of Solomon Burke
#
#         spotify_track_explicit  spotify_track_duration_ms  \
# 0                          0.0                   270740.0
# 1                          0.0                   270740.0
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 321013                     0.0                   161186.0
# 321014                     0.0                   161186.0
# 321015                     0.0                   161186.0
# 321016                     0.0                   161186.0
# 321017                     0.0                   161186.0
#
#         spotify_track_popularity  danceability  ...    tempo  time_signature  \
# 0                           91.0         0.734  ...   80.002             4.0
# 1                           91.0         0.734  ...   80.002             4.0
# 2                            NaN           NaN  ...      NaN             NaN
# 3                            NaN           NaN  ...      NaN             NaN
# 4                            NaN           NaN  ...      NaN             NaN
# ...                          ...           ...  ...      ...             ...
# 321013                      28.0         0.318  ...  173.305             3.0
# 321014                      28.0         0.318  ...  173.305             3.0
# 321015                      28.0         0.318  ...  173.305             3.0
# 321016                      28.0         0.318  ...  173.305             3.0
# 321017                      28.0         0.318  ...  173.305             3.0
#
#            week_id  week_pos                                 track_y  \
# 0       2019-10-12        98                                  Adicto
# 1       2019-10-05        86                                  Adicto
# 2       2019-10-12        92  The Ones That Didn't Make It Back Home
# 3       2019-10-05        72  The Ones That Didn't Make It Back Home
# 4       2019-09-28        66  The Ones That Didn't Make It Back Home
# ...            ...       ...                                     ...
# 321013  1965-06-26        42                     Tonight's The Night
# 321014  1965-06-19        54                     Tonight's The Night
# 321015  1965-06-12        70                     Tonight's The Night
# 321016  1965-06-05        70                     Tonight's The Night
# 321017  1965-05-29        80                     Tonight's The Night
#
#                        artist_y  instance  prev_week_pos  peak_pos  \
# 0       Tainy, Anuel AA & Ozuna         1           86.0        86
# 1       Tainy, Anuel AA & Ozuna         1            NaN        86
# 2                  Justin Moore         1           72.0        46
# 3                  Justin Moore         1           66.0        46
# 4                  Justin Moore         1           66.0        46
# ...                         ...       ...            ...       ...
# 321013            Solomon Burke         1           54.0        42
# 321014            Solomon Burke         1           70.0        54
# 321015            Solomon Burke         1           70.0        70
# 321016            Solomon Burke         1           80.0        70
# 321017            Solomon Burke         1            NaN        80
#
#         weeks_on_chart
# 0                    2
# 1                    1
# 2                   16
# 3                   15
# 4                   14
# ...                ...
# 321013               5
# 321014               4
# 321015               3
# 321016               2
# 321017               1
#
# [321018 rows x 29 columns]

# %%
del billboard_audio['track_y']
del billboard_audio['artist_y']

billboard_audio = billboard_audio.rename(columns={'track_x': 'track', 'artist_x':'artist'})

# %%
drop_null = billboard_audio.dropna()
cleaned_billboard_audio = drop_null.drop_duplicates()
cleaned_billboard_audio
# Out:
#                                  track_id                      artist  \
# 0           AdictoTainy, Anuel AA & Ozuna     Tainy, Anuel AA & Ozuna
# 18      ShallowLady Gaga & Bradley Cooper  Lady Gaga & Bradley Cooper
# 19      ShallowLady Gaga & Bradley Cooper  Lady Gaga & Bradley Cooper
# 20      ShallowLady Gaga & Bradley Cooper  Lady Gaga & Bradley Cooper
# 21      ShallowLady Gaga & Bradley Cooper  Lady Gaga & Bradley Cooper
# ...                                   ...                         ...
# 321012   Tonight's The NightSolomon Burke               Solomon Burke
# 321013   Tonight's The NightSolomon Burke               Solomon Burke
# 321014   Tonight's The NightSolomon Burke               Solomon Burke
# 321015   Tonight's The NightSolomon Burke               Solomon Burke
# 321016   Tonight's The NightSolomon Burke               Solomon Burke
#
#                       track  \
# 0                    Adicto
# 18                  Shallow
# 19                  Shallow
# 20                  Shallow
# 21                  Shallow
# ...                     ...
# 321012  Tonight's The Night
# 321013  Tonight's The Night
# 321014  Tonight's The Night
# 321015  Tonight's The Night
# 321016  Tonight's The Night
#
#                                             spotify_genre  \
# 0                                       ['pop reggaeton']
# 18                                   ['dance pop', 'pop']
# 19                                   ['dance pop', 'pop']
# 20                                   ['dance pop', 'pop']
# 21                                   ['dance pop', 'pop']
# ...                                                   ...
# 321012  ['brill building pop', 'classic soul', 'funk',...
# 321013  ['brill building pop', 'classic soul', 'funk',...
# 321014  ['brill building pop', 'classic soul', 'funk',...
# 321015  ['brill building pop', 'classic soul', 'funk',...
# 321016  ['brill building pop', 'classic soul', 'funk',...
#
#               spotify_track_id             spotify_track_album  \
# 0       3jbT1Y5MoPwEIpZndDDwVq  Adicto (with Anuel AA & Ozuna)
# 18      2VxeLyX666F8uXCJ0dZF8B       A Star Is Born Soundtrack
# 19      2VxeLyX666F8uXCJ0dZF8B       A Star Is Born Soundtrack
# 20      2VxeLyX666F8uXCJ0dZF8B       A Star Is Born Soundtrack
# 21      2VxeLyX666F8uXCJ0dZF8B       A Star Is Born Soundtrack
# ...                        ...                             ...
# 321012  18TM70njJRFH4Fm4ZuwLd8  The Very Best Of Solomon Burke
# 321013  18TM70njJRFH4Fm4ZuwLd8  The Very Best Of Solomon Burke
# 321014  18TM70njJRFH4Fm4ZuwLd8  The Very Best Of Solomon Burke
# 321015  18TM70njJRFH4Fm4ZuwLd8  The Very Best Of Solomon Burke
# 321016  18TM70njJRFH4Fm4ZuwLd8  The Very Best Of Solomon Burke
#
#         spotify_track_explicit  spotify_track_duration_ms  \
# 0                          0.0                   270740.0
# 18                         0.0                   215733.0
# 19                         0.0                   215733.0
# 20                         0.0                   215733.0
# 21                         0.0                   215733.0
# ...                        ...                        ...
# 321012                     0.0                   161186.0
# 321013                     0.0                   161186.0
# 321014                     0.0                   161186.0
# 321015                     0.0                   161186.0
# 321016                     0.0                   161186.0
#
#         spotify_track_popularity  danceability  ...  liveness  valence  \
# 0                           91.0         0.734  ...     0.179    0.623
# 18                          88.0         0.572  ...     0.231    0.323
# 19                          88.0         0.572  ...     0.231    0.323
# 20                          88.0         0.572  ...     0.231    0.323
# 21                          88.0         0.572  ...     0.231    0.323
# ...                          ...           ...  ...       ...      ...
# 321012                      28.0         0.318  ...     0.600    0.633
# 321013                      28.0         0.318  ...     0.600    0.633
# 321014                      28.0         0.318  ...     0.600    0.633
# 321015                      28.0         0.318  ...     0.600    0.633
# 321016                      28.0         0.318  ...     0.600    0.633
#
#           tempo  time_signature     week_id  week_pos  instance  \
# 0        80.002             4.0  2019-10-12        98         1
# 18       95.799             4.0  2019-08-17        49         1
# 19       95.799             4.0  2019-08-10        47         1
# 20       95.799             4.0  2019-08-03        47         1
# 21       95.799             4.0  2019-07-27        48         1
# ...         ...             ...         ...       ...       ...
# 321012  173.305             3.0  1965-07-03        32         1
# 321013  173.305             3.0  1965-06-26        42         1
# 321014  173.305             3.0  1965-06-19        54         1
# 321015  173.305             3.0  1965-06-12        70         1
# 321016  173.305             3.0  1965-06-05        70         1
#
#         prev_week_pos  peak_pos  weeks_on_chart
# 0                86.0        86               2
# 18               47.0         1              45
# 19               47.0         1              44
# 20               48.0         1              43
# 21               45.0         1              42
# ...               ...       ...             ...
# 321012           42.0        32               6
# 321013           54.0        42               5
# 321014           70.0        54               4
# 321015           70.0        70               3
# 321016           80.0        70               2
#
# [252690 rows x 27 columns]

# %%
X = cleaned_billboard_audio[[spotify_track_explicit,spotify_track_duration_ms,spotify_track_popularity,danceability,energy,key,loudness,mode,speechiness,acousticness,instrumentalness,liveness,valence,'tempo','time_signature','week_pos','instance','peak_pos']]
y = cleaned_billboard_audio.weeks_on_chart.values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (252690, 10) (252690, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)
model.fit(X_train, y_train)
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test.min(), xmax=y_test.max())
plt.title("Residual Plot")
plt.show()

# %%
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test, predictions)
r2 = model.score(X_test, y_test)


print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 35.304067131775916, R2: 0.3779558406218225
