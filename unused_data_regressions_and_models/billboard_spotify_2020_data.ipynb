# %%
from spotipy.oauth2 import SpotifyClientCredentials
import json
import spotipy
import time
import billboard
import requests
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id ="e43221c7ee8b49378e39b214ae4c9eb7",client_secret ="8f56195536c74401ac8428d2afbbc2b1"))

# %%
chart = billboard.ChartData('hot-100')
print(len(chart))

tracks =[]
artists = []
for i in range(len(chart)):
    tracks.append(chart[i].title)
    artists.append(chart[i].artist)
print(len(tracks))
print(len(artists))
# Out:
# 100
# 100
# 100

# %%
sp.trace = True

track_ids = []

for track in tracks:
    results = sp.search(q=track, limit=1)

    for i, t in enumerate(results['tracks']['items']):
        track_ids.append(t['uri'])


features = sp.audio_features(track_ids)

for feature in features:
    print(json.dumps(feature, indent=4))
# Out:
# {
#     "danceability": 0.767,
#     "energy": 0.481,
#     "key": 0,
#     "loudness": -8.52,
#     "mode": 0,
#     "speechiness": 0.0803,
#     "acousticness": 0.234,
#     "instrumentalness": 0,
#     "liveness": 0.269,
#     "valence": 0.761,
#     "tempo": 150.076,
#     "type": "audio_features",
#     "id": "1xQ6trAsedVPCdbtDAmk0c",
#     "uri": "spotify:track:1xQ6trAsedVPCdbtDAmk0c",
#     "track_href": "https://api.spotify.com/v1/tracks/1xQ6trAsedVPCdbtDAmk0c",
#     "analysis_url": "https://api.spotify.com/v1/audio-analysis/1xQ6trAsedVPCdbtDAmk0c",
#     "duration_ms": 171375,
#     "time_signature": 4
# }
# {
#     "danceability": 0.746,
#     "energy": 0.765,
#     "key": 6,
#     "loudness": -4.41,
#     "mode": 0,
#     "speechiness": 0.0993,
#     "acousticness": 0.0112,
#     "instrumentalness": 0,
#     "liveness": 0.0936,
#     "valence": 0.737,
#     "tempo": 114.044,
#     "type": "audio_features",
#     "id": "0t1kP63rueHleOhQkYSXFY",
# ...

# %%
print(len(features))
# Out:
# 100
